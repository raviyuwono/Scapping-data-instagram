# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'harvestcakes'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Ganti class sesuai hasil inspect element di browser
    kategori_akun = profile_soup.find('div', {'class': '_aa_c'}).text.strip()
except:
    kategori_akun = ''
print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 50
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya"
    while True:
        try:
            load_more = driver.find_element(
                By.XPATH,
                "//button[.//svg[@aria-label='Muat komentar lainnya'] or .//svg[@aria-label='Load more comments']]"
            )
            load_more.click()
            time.sleep(2)
        except NoSuchElementException:
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        caption = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade').text
    except:
        caption = ''

    try:
        likes_div = soup.find('a', class_='x1i10hfl xjbqb8w ...')  # Ganti class sesuai hasil inspect
        likes = likes_div.text if likes_div else ''
    except:
        likes = ''

    try:
        comments_divs = soup.find_all('div', class_='x9f619 xjbqb8w x78zum5 x15mokao x1ga7v0g x16uus16 xbiv7yw x1yztbdb x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1')  # Ganti class sesuai hasil inspect
        comments_count = len(comments_divs)
    except:
        comments_count = 0

    try:
        media = soup.find('img')
        if media:
            media_url = media['src']
        else:
            video = soup.find('video')
            media_url = video['src'] if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except:
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'theHarvest post'

    data.append((
        brand, link, caption, likes, comments_count, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Dominant: {dominant_color} | Name: {color_name}")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_theHarvest.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_TheHarvest.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun:
# ✅ Total post ditemukan: 42
# [1] ✅ https://www.instagram.com/harvestcakes/p/C9glh1ePpn2/ | post | Dominant: (241, 224, 209) | Name: unknown
# [2] ✅ https://www.instagram.com/harvestcakes/p/C9glRaNRA_R/ | post | Dominant: (237, 208, 192) | Name: unknown
# [3] ✅ https://www.instagram.com/harvestcakes/p/C9gf5haRWLK/ | post | Dominant: (237, 230, 220) | Name: unknown
# [4] ✅ https://www.instagram.com/harvestcakes/p/C9gWxF0SOGV/ | post | Dominant: (228, 215, 203) | Name: unknown
# [5] ✅ https://www.instagram.com/harvestcakes/p/C9gULSby-7R/ | post | Dominant: (226, 219, 212) | Name: unknown
# [6] ✅ https://www.instagram.com/bekasi.terkini/reel/C9cBwK2SxfH/ | reel | Dominant:  | Name:
# [7] ✅ https://www.instagram.com/harvestcakes/p/C9bmMR6J3uL/ | post | Dominant: (241, 221, 214) | Name: unknown
# [8] ✅ https://www.instagram.com/harvestcakes/reel/C9Zri-gJ88p/ | reel | Dominant:  | Name:
# [9] ✅ https://www.instagram.com/harvestcakes/p/C9Zlj_fJSH7/ | post | Dominant: (239, 229, 214) | Name: unknown
# [10] ✅ https://www.instagram.com/harvestcakes/reel/C9XLqabJzl_/ | reel | Dominant:  | Name:
# [11] ✅ https://www.instagram.com/harvestcakes/reel/C9WJGQsyc4f/ | reel | Dominant:  | Name:
# [12] ✅ https://www.instagram.com/harvestcakes/reel/C9UnxJJJvRf/ | reel | Dominant:  | Name:
# [13] ✅ https://www.instagram.com/harvestcakes/reel/C9SEGEPpuBF/ | reel | Dominant:  | Name:
# [14] ✅ https://www.instagram.com/harvestcakes/reel/C9RuOJARWmi/ | reel | Dominant:  | Name:
# [15] ✅ https://www.instagram.com/harvestcakes/p/C9RbOd6xX9t/ | post | Dominant: (131, 77, 46) | Name: unknown
# [16] ✅ https://www.instagram.com/harvestcakes/reel/C9PdSLcJUZJ/ | reel | Dominant:  | Name:
# [17] ✅ https://www.instagram.com/harvestcakes/reel/C9PLGlmRA-z/ | reel | Dominant:  | Name:
# [18] ✅ https://www.instagram.com/harvestcakes/p/C9OeNuYx8qZ/ | post | Dominant: (226, 229, 218) | Name: unknown
# [19] ✅ https://www.instagram.com/harvestcakes/p/C9MukmSJP8K/ | post | Dominant: (185, 214, 185) | Name: unknown
# [20] ✅ https://www.instagram.com/harvestcakes/p/C9KTrcIJckZ/ | post | Dominant: (222, 217, 228) | Name: unknown
# [21] ✅ https://www.instagram.com/harvestcakes/p/C9KMa0yRU0W/ | post | Dominant: (126, 32, 40) | Name: unknown
# [22] ✅ https://www.instagram.com/harvestcakes/reel/C9Gr2iWxIB1/ | reel | Dominant:  | Name:
# [23] ✅ https://www.instagram.com/harvestcakes/reel/C9FCfULxVKZ/ | reel | Dominant:  | Name:
# [24] ✅ https://www.instagram.com/harvestcakes/reel/C9ETW-7RMkE/ | reel | Dominant:  | Name:
# [25] ✅ https://www.instagram.com/harvestcakes/p/C9EAKZCyNNo/ | post | Dominant: (232, 220, 207) | Name: unknown
# [26] ✅ https://www.instagram.com/radarkediri/reel/C9Cskm-vWyA/ | reel | Dominant:  | Name:
# [27] ✅ https://www.instagram.com/harvestcakes/p/C9Ck17XpaJ9/ | post | Dominant: (238, 229, 220) | Name: unknown
# [28] ✅ https://www.instagram.com/harvestcakes/reel/C9Cbhs5xBaY/ | reel | Dominant:  | Name:
# [29] ✅ https://www.instagram.com/harvestcakes/reel/C9CVJ_oRO5g/ | reel | Dominant:  | Name:
# [30] ✅ https://www.instagram.com/harvestcakes/p/C9CNnsfR0c7/ | post | Dominant: (236, 182, 74) | Name: unknown
# [31] ✅ https://www.instagram.com/harvestcakes/p/C9B8p3bRq0l/ | post | Dominant: (227, 195, 193) | Name: unknown
# [32] ✅ https://www.instagram.com/harvestcakes/p/C9B0q6ERY_g/ | post | Dominant: (200, 150, 158) | Name: unknown
# [33] ✅ https://www.instagram.com/harvestcakes/reel/C8_3UB5xYp2/ | reel | Dominant:  | Name:
# [34] ✅ https://www.instagram.com/harvestcakes/reel/C8_rQB5RYhf/ | reel | Dominant:  | Name:
# [35] ✅ https://www.instagram.com/kuliner_bekasi_hits/reel/C89cbNtPIg7/ | reel | Dominant:  | Name:
# [36] ✅ https://www.instagram.com/harvestcakes/p/C89T1ClpTKQ/ | post | Dominant: (229, 217, 211) | Name: unknown
# [37] ✅ https://www.instagram.com/harvestcakes/p/C860cmDpz2p/ | post | Dominant: (226, 215, 204) | Name: unknown
# [38] ✅ https://www.instagram.com/harvestcakes/p/C86tOOsxWHm/ | post | Dominant: (205, 206, 193) | Name: unknown
# [39] ✅ https://www.instagram.com/harvestcakes/p/C83htnHRpaj/ | post | Dominant: (215, 180, 185) | Name: unknown
# [40] ✅ https://www.instagram.com/harvestcakes/reel/C81RcrExVGV/ | reel | Dominant:  | Name:
# [41] ✅ https://www.instagram.com/brigittairene22/reel/C80vRH-SiOi/ | reel | Dominant:  | Name:
# [42] ✅ https://www.instagram.com/harvestcakes/p/C80oLyHyoQS/ | post | Dominant: (166, 140, 128) | Name: unknown
#
# ✅ Selesai! Data disimpan ke 'konten_ig_TheHarvest.xlsx'
