# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'kfcindonesia'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Ganti class sesuai hasil inspect element di browser
    kategori_akun = profile_soup.find('div', {'class': '_aa_c'}).text.strip()
except:
    kategori_akun = ''
print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 50
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya"
    while True:
        try:
            load_more = driver.find_element(
                By.XPATH,
                "//button[.//svg[@aria-label='Muat komentar lainnya'] or .//svg[@aria-label='Load more comments']]"
            )
            load_more.click()
            time.sleep(2)
        except NoSuchElementException:
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        caption = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade').text
    except:
        caption = ''

    try:
        likes_div = soup.find('a', class_='x1i10hfl xjbqb8w ...')  # Ganti class sesuai hasil inspect
        likes = likes_div.text if likes_div else ''
    except:
        likes = ''

    try:
        comments_divs = soup.find_all('div', class_='x9f619 xjbqb8w x78zum5 x15mokao x1ga7v0g x16uus16 xbiv7yw x1yztbdb x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1')  # Ganti class sesuai hasil inspect
        comments_count = len(comments_divs)
    except:
        comments_count = 0

    try:
        media = soup.find('img')
        if media:
            media_url = media['src']
        else:
            video = soup.find('video')
            media_url = video['src'] if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except:
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'KFC Post'

    data.append((
        brand, link, caption, likes, comments_count, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Dominant: {dominant_color} | Name: {color_name}")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_kfc.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_with_category.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun:
# ✅ Total post ditemukan: 42
# [1] ✅ https://www.instagram.com/aerostreet/p/Cwe_JIsSvx_/ | post | Dominant: (226, 6, 37) | Name: unknown
# [2] ✅ https://www.instagram.com/kfcindonesia/p/Cwe22g8SMus/ | post | Dominant: (222, 175, 162) | Name: unknown
# [3] ✅ https://www.instagram.com/aerostreet/p/Cwecp5tyIVw/ | post | Dominant: (168, 15, 32) | Name: unknown
# [4] ✅ https://www.instagram.com/kfcindonesia/p/CwcoH7ky88B/ | post | Dominant: (25, 18, 14) | Name: unknown
# [5] ✅ https://www.instagram.com/aerostreet/p/CwcaNXKylBe/ | post | Dominant: (198, 6, 36) | Name: unknown
# [6] ✅ https://www.instagram.com/kfcindonesia/reel/CwcS02soclQ/ | reel | Dominant:  | Name:
# [7] ✅ https://www.instagram.com/kfcindonesia/p/Cwb2C-syCc8/ | post | Dominant: (19, 85, 155) | Name: unknown
# [8] ✅ https://www.instagram.com/kfcindonesia/p/CwZNW3vyUN8/ | post | Dominant: (22, 18, 17) | Name: unknown
# [9] ✅ https://www.instagram.com/kfcindonesia/p/CwWsitzSOb9/ | post | Dominant: (19, 56, 98) | Name: unknown
# [10] ✅ https://www.instagram.com/kfcindonesia/p/CwUJaFpSKOa/ | post | Dominant: (244, 235, 225) | Name: unknown
# [11] ✅ https://www.instagram.com/kfcindonesia/p/CwT1Hz9ykAe/ | post | Dominant: (160, 72, 33) | Name: unknown
# [12] ✅ https://www.instagram.com/kfcindonesia/p/CwSEaGnyWix/ | post | Dominant: (153, 52, 49) | Name: unknown
# [13] ✅ https://www.instagram.com/kfcindonesia/p/CwRjh9iyMSK/ | post | Dominant: (33, 83, 145) | Name: unknown
# [14] ✅ https://www.instagram.com/kfcindonesia/p/CwPnIcnS0wK/ | post | Dominant: (201, 189, 204) | Name: unknown
# [15] ✅ https://www.instagram.com/kfcindonesia/p/CwPZvUxy4XW/ | post | Dominant: (31, 21, 18) | Name: unknown
# [16] ✅ https://www.instagram.com/kfcindonesia/p/CwO7SE1y7gc/ | post | Dominant: (36, 39, 45) | Name: unknown
# [17] ✅ https://www.instagram.com/kfcindonesia/p/CwKahBtSwy6/ | post | Dominant: (24, 19, 19) | Name: unknown
# [18] ✅ https://www.instagram.com/kfcindonesia/p/CwJxXhuyhLT/ | post | Dominant: (52, 49, 47) | Name: unknown
# [19] ✅ https://www.instagram.com/aerostreet/reel/CwJgtQ0Ndm5/ | reel | Dominant:  | Name:
# [20] ✅ https://www.instagram.com/kfcindonesia/reel/CwHuoUboHQq/ | reel | Dominant:  | Name:
# [21] ✅ https://www.instagram.com/aerostreet/reel/CwHZ7iStW5W/ | reel | Dominant:  | Name:
# [22] ✅ https://www.instagram.com/kfcindonesia/reel/CwHNVB1o3fo/ | reel | Dominant:  | Name:
# [23] ✅ https://www.instagram.com/kfcindonesia/reel/CwFRjdSINN6/ | reel | Dominant:  | Name:
# [24] ✅ https://www.instagram.com/kfcindonesia/p/CwE9ztlS4zJ/ | post | Dominant: (210, 27, 31) | Name: unknown
# [25] ✅ https://www.instagram.com/kfcindonesia/p/CwBs425PIwg/ | post | Dominant: (28, 19, 21) | Name: unknown
# [26] ✅ https://www.instagram.com/kfcindonesia/p/CwBl7l-PEo7/ | post | Dominant: (231, 214, 204) | Name: unknown
# [27] ✅ https://www.instagram.com/kfcindonesia/reel/Cv_6WAnNs8I/ | reel | Dominant:  | Name:
# [28] ✅ https://www.instagram.com/kfcindonesia/p/Cv_lE1ySYCk/ | post | Dominant: (34, 47, 35) | Name: unknown
# [29] ✅ https://www.instagram.com/kfcindonesia/p/Cv_ghFdyNM7/ | post | Dominant: (222, 216, 208) | Name: unknown
# [30] ✅ https://www.instagram.com/kfcindonesia/p/Cv9fRZQyihO/ | post | Dominant: (203, 49, 47) | Name: unknown
# [31] ✅ https://www.instagram.com/kfcindonesia/p/Cv9QjxbyNNh/ | post | Dominant: (25, 5, 5) | Name: unknown
# [32] ✅ https://www.instagram.com/kfcindonesia/p/Cv80YwhS6ge/ | post | Dominant: (194, 59, 50) | Name: unknown
# [33] ✅ https://www.instagram.com/kfcindonesia/reel/Cv4bs16N0Uh/ | reel | Dominant:  | Name:
# [34] ✅ https://www.instagram.com/kfcindonesia/p/Cv3xNE8ScSn/ | post | Dominant: (239, 218, 222) | Name: unknown
# [35] ✅ https://www.instagram.com/kfcindonesia/reel/Cv1yKJfNgfd/ | reel | Dominant:  | Name:
# [36] ✅ https://www.instagram.com/kfcindonesia/p/Cv1Z8zhyxKW/ | post | Dominant: (233, 220, 206) | Name: unknown
# [37] ✅ https://www.instagram.com/kfcindonesia/reel/Cv1Gwc7NU4v/ | reel | Dominant:  | Name:
# [38] ✅ https://www.instagram.com/kfcindonesia/p/CvzMddkyLeu/ | post | Dominant: (234, 120, 107) | Name: unknown
# [39] ✅ https://www.instagram.com/kfcindonesia/p/CvyoBJLSR_l/ | post | Dominant: (190, 193, 188) | Name: unknown
# [40] ✅ https://www.instagram.com/kfcindonesia/p/CvyWlcMy9Ls/ | post | Dominant: (223, 211, 200) | Name: unknown
# [41] ✅ https://www.instagram.com/kfcindonesia/p/CvwC1JFySX3/ | post | Dominant: (191, 18, 13) | Name: unknown
# [42] ✅ https://www.instagram.com/kfcindonesia/reel/CvvvL_uNly9/ | reel | Dominant:  | Name:
#
# ✅ Selesai! Data disimpan ke 'konten_ig_with_category.xlsx'
