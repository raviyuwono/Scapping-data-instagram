# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'kopikenangan.id'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Ganti class sesuai hasil inspect element di browser
    kategori_akun = profile_soup.find('div', {'class': '_aa_c'}).text.strip()
except:
    kategori_akun = ''
print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 50
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya"
    while True:
        try:
            load_more = driver.find_element(
                By.XPATH,
                "//button[.//svg[@aria-label='Muat komentar lainnya'] or .//svg[@aria-label='Load more comments']]"
            )
            load_more.click()
            time.sleep(2)
        except NoSuchElementException:
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        caption = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade').text
    except:
        caption = ''

    try:
        likes_div = soup.find('a', class_='x1i10hfl xjbqb8w ...')  # Ganti class sesuai hasil inspect
        likes = likes_div.text if likes_div else ''
    except:
        likes = ''

    try:
        comments_divs = soup.find_all('div', class_='x9f619 xjbqb8w x78zum5 x15mokao x1ga7v0g x16uus16 xbiv7yw x1yztbdb x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1')  # Ganti class sesuai hasil inspect
        comments_count = len(comments_divs)
    except:
        comments_count = 0

    try:
        media = soup.find('img')
        if media:
            media_url = media['src']
        else:
            video = soup.find('video')
            media_url = video['src'] if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except:
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'Kopi Kenangan post'

    data.append((
        brand, link, caption, likes, comments_count, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Dominant: {dominant_color} | Name: {color_name}")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_KopiKenangan.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_KopiKenangan.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun:
# ✅ Total post ditemukan: 42
# [1] ✅ https://www.instagram.com/kopikenangan.id/p/Cxpfu3lhECV/ | post | Dominant: (217, 206, 189) | Name: unknown
# [2] ✅ https://www.instagram.com/kopikenangan.id/reel/Cxm7XptBEVX/ | reel | Dominant:  | Name:
# [3] ✅ https://www.instagram.com/kopikenangan.id/reel/CxmK4EchWrx/ | reel | Dominant:  | Name:
# [4] ✅ https://www.instagram.com/kopikenangan.id/p/CxfZKGChQpg/ | post | Dominant: (247, 235, 220) | Name: unknown
# [5] ✅ https://www.instagram.com/kopikenangan.id/p/CxfKbUPBFbT/ | post | Dominant: (147, 167, 83) | Name: unknown
# [6] ✅ https://www.instagram.com/kopikenangan.id/p/CxaUaSWB_kO/ | post | Dominant: (10, 10, 10) | Name: unknown
# [7] ✅ https://www.instagram.com/kopikenangan.id/p/CxXbbXVhl2F/ | post | Dominant: (215, 218, 178) | Name: unknown
# [8] ✅ https://www.instagram.com/kopikenangan.id/reel/CxWxEtQhhrP/ | reel | Dominant:  | Name:
# [9] ✅ https://www.instagram.com/kopikenangan.id/p/CxUuTZwhRjF/ | post | Dominant: (51, 46, 43) | Name: unknown
# [10] ✅ https://www.instagram.com/kopikenangan.id/p/CxUmDgmB_rl/ | post | Dominant: (243, 232, 201) | Name: unknown
# [11] ✅ https://www.instagram.com/kopikenangan.id/reel/CxPNP4BhDad/ | reel | Dominant:  | Name:
# [12] ✅ https://www.instagram.com/kopikenangan.id/reel/CxM1KuYBGkt/ | reel | Dominant:  | Name:
# [13] ✅ https://www.instagram.com/kopikenangan.id/p/CxK4TR2hPfx/ | post | Dominant: (218, 180, 169) | Name: unknown
# [14] ✅ https://www.instagram.com/kopikenangan.id/reel/CxFobjShECf/ | reel | Dominant:  | Name:
# [15] ✅ https://www.instagram.com/kopikenangan.id/p/CxFADhshHyE/ | post | Dominant: (232, 205, 184) | Name: unknown
# [16] ✅ https://www.instagram.com/kopikenangan.id/p/CxDCdeMh5k2/ | post | Dominant: (87, 103, 50) | Name: unknown
# [17] ✅ https://www.instagram.com/kopikenangan.id/p/CxC0PfuBzPk/ | post | Dominant: (192, 201, 197) | Name: unknown
# [18] ✅ https://www.instagram.com/kopikenangan.id/reel/Cw_7wkGBtP2/ | reel | Dominant:  | Name:
# [19] ✅ https://www.instagram.com/kopikenangan.id/p/Cw5Az_IhwN3/ | post | Dominant: (248, 232, 219) | Name: unknown
# [20] ✅ https://www.instagram.com/kopikenangan.id/p/Cw1_6VWhpCg/ | post | Dominant: (223, 220, 180) | Name: unknown
# [21] ✅ https://www.instagram.com/kopikenangan.id/p/Cwzbl53hG-B/ | post | Dominant: (221, 209, 196) | Name: unknown
# [22] ✅ https://www.instagram.com/kopikenangan.id/reel/CwxI3EHhJKh/ | reel | Dominant:  | Name:
# [23] ✅ https://www.instagram.com/kopikenangan.id/reel/CwrYlnIB_UO/ | reel | Dominant:  | Name:
# [24] ✅ https://www.instagram.com/kopikenangan.id/p/CwrA7yjhCnp/ | post | Dominant: (243, 231, 219) | Name: unknown
# [25] ✅ https://www.instagram.com/kopikenangan.id/p/CworTALBu52/ | post | Dominant: (75, 100, 54) | Name: unknown
# [26] ✅ https://www.instagram.com/kopikenangan.id/reel/CwooKQqBwUR/ | reel | Dominant:  | Name:
# [27] ✅ https://www.instagram.com/kopikenangan.id/p/CwoiGzThySj/ | post | Dominant: (81, 109, 52) | Name: unknown
# [28] ✅ https://www.instagram.com/kopikenangan.id/p/CwmzGS2hVRa/ | post | Dominant: (32, 38, 51) | Name: unknown
# [29] ✅ https://www.instagram.com/kopikenangan.id/reel/Cwmmlfkh035/ | reel | Dominant:  | Name:
# [30] ✅ https://www.instagram.com/kopikenangan.id/p/CwmfEoRBohc/ | post | Dominant: (199, 189, 179) | Name: unknown
# [31] ✅ https://www.instagram.com/kopikenangan.id/reel/CwkS4IYBcdv/ | reel | Dominant:  | Name:
# [32] ✅ https://www.instagram.com/kopikenangan.id/p/Cwj_l1bBJ7N/ | post | Dominant: (200, 166, 141) | Name: unknown
# [33] ✅ https://www.instagram.com/kopikenangan.id/reel/CwhxdHyhIFt/ | reel | Dominant:  | Name:
# [34] ✅ https://www.instagram.com/kopikenangan.id/p/CwbkaIGhePl/ | post | Dominant: (232, 208, 202) | Name: unknown
# [35] ✅ https://www.instagram.com/kopikenangan.id/p/CwWubPyBgBV/ | post | Dominant: (147, 71, 47) | Name: unknown
# [36] ✅ https://www.instagram.com/kopikenangan.id/p/CwUvQ5mBs-z/ | post | Dominant: (235, 220, 203) | Name: unknown
# [37] ✅ https://www.instagram.com/kopikenangan.id/reel/CwUATJ1BVja/ | reel | Dominant:  | Name:
# [38] ✅ https://www.instagram.com/kopikenangan.id/p/CwSQTUiB2tk/ | post | Dominant: (203, 125, 100) | Name: unknown
# [39] ✅ https://www.instagram.com/kopikenangan.id/p/CwRlwG0BXU1/ | post | Dominant: (219, 194, 171) | Name: unknown
# [40] ✅ https://www.instagram.com/kopikenangan.id/p/CwPigzAh3no/ | post | Dominant: (244, 226, 208) | Name: unknown
# [41] ✅ https://www.instagram.com/kopikenangan.id/reel/CwPTBy4hFMJ/ | reel | Dominant:  | Name:
# [42] ✅ https://www.instagram.com/kopikenangan.id/p/CwMbtKxBrqG/ | post | Dominant: (223, 197, 187) | Name: unknown
#
# ✅ Selesai! Data disimpan ke 'konten_ig_KopiKenangan.xlsx'
