# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors
import re

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Fungsi untuk mengambil comments ===
def get_comments_data(driver, soup):
    comments_data = []
    comments_count = 0

    try:
        # Temukan semua komentar berdasarkan struktur baru
        comment_spans = soup.find_all('span', {'dir': 'auto'})

        for span in comment_spans:
            text = span.get_text(strip=True)
            # Filter komentar valid
            if (
                text and len(text) > 1
                and not text.startswith('@')  # bukan mention
                and not any(keyword in text.lower() for keyword in [
                    'like', 'reply', 'view', 'follow', 'ago', 'hour', 'day', 'week',
                    'menit', 'minute', 'disukai', 'balas'
                ])
            ):
                comments_data.append(text)
                comments_count += 1

    except Exception as e:
        print(f"Error getting comments: {e}")

    return comments_data, comments_count


# === Fungsi untuk mengambil likes dengan lebih akurat ===
def get_likes_count(soup):
    try:
        # First check for "No likes yet" case
        no_likes = soup.find(string=re.compile(r'No likes yet|Belum ada yang menyukai', re.I))
        if no_likes:
            return '0'
            
        # Method 1: Look for like count in meta description
        meta_desc = soup.find('meta', {'name': 'description'})
        if meta_desc:
            desc = meta_desc.get('content', '')
            match = re.search(r'(\d+(?:,\d+)*) Likes|(\d+(?:,\d+)*) suka', desc)
            if match:
                return match.group(1) or match.group(2)
                
        # Method 2: Look for like count in buttons
        like_buttons = soup.find_all('button', string=re.compile(r'\d+ Likes|\d+ suka', re.I))
        for button in like_buttons:
            numbers = re.findall(r'[\d,]+', button.get_text())
            if numbers:
                return numbers[0]
                
        # Method 3: Look for like count in spans
        spans = soup.find_all('span')
        for span in spans:
            text = span.get_text()
            if 'like' in text.lower() and any(char.isdigit() for char in text):
                numbers = re.findall(r'[\d,]+', text)
                if numbers:
                    return numbers[0]
                    
    except Exception as e:
        print(f"Error getting likes: {e}")
    
    return ''

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'batikula'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Cari dengan berbagai metode
    kategori_akun = ''
    
    # Metode 1: Cari berdasarkan struktur profile
    category_divs = profile_soup.find_all('div', string=re.compile(r'Business|Shopping|Brand|Store', re.I))
    if category_divs:
        kategori_akun = category_divs[0].get_text().strip()
    
    # Metode 2: Backup jika tidak ketemu
    if not kategori_akun:
        bio_sections = profile_soup.find_all('div', {'class': re.compile(r'_aa_c')})
        for section in bio_sections:
            text = section.get_text().strip()
            if text and len(text) < 100:  # Kategori biasanya pendek
                kategori_akun = text
                break
                
except Exception as e:
    kategori_akun = ''
    print(f"Error getting category: {e}")

print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 5
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya" dengan lebih banyak variasi
    load_more_attempts = 0
    max_load_attempts = 3
    
    while load_more_attempts < max_load_attempts:
        try:
            # Coba berbagai selector untuk tombol load more
            load_more_selectors = [
                "//button[.//svg[@aria-label='Muat komentar lainnya']]",
                "//button[.//svg[@aria-label='Load more comments']]",
                "//button[contains(text(), 'View more comments')]",
                "//button[contains(text(), 'Lihat komentar lainnya')]",
                "//span[contains(text(), 'View more comments')]",
                "//span[contains(text(), 'Lihat komentar lainnya')]"
            ]
            
            load_more_found = False
            for selector in load_more_selectors:
                try:
                    load_more = driver.find_element(By.XPATH, selector)
                    load_more.click()
                    load_more_found = True
                    time.sleep(2)
                    break
                except NoSuchElementException:
                    continue
            
            if not load_more_found:
                break
                
            load_more_attempts += 1
            
        except Exception as e:
            print(f"Error loading more comments: {e}")
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        # Cari caption dengan berbagai metode
        caption = ''
        
        # Metode 1: Cari h1 dengan class spesifik
        caption_h1 = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade')
        if caption_h1:
            caption = caption_h1.get_text().strip()
        
        # Metode 2: Cari berdasarkan struktur yang lebih umum
        if not caption:
            meta_desc = soup.find('meta', {'name': 'description'})
            if meta_desc:
                caption = meta_desc.get('content', '')
        
        # Metode 3: Cari span dengan teks panjang di area post
        if not caption:
            spans = soup.find_all('span', dir='auto')
            for span in spans:
                text = span.get_text().strip()
                if len(text) > 20:  # Caption biasanya lebih panjang
                    caption = text
                    break
                    
    except Exception as e:
        caption = ''
        print(f"Error getting caption: {e}")

    # Ambil likes dengan fungsi yang diperbaiki
    likes = get_likes_count(soup)

    # Ambil comments dengan fungsi yang diperbaiki
    comments_data, comments_count = get_comments_data(driver, soup)

    try:
        media = soup.find('img')
        if media:
            media_url = media.get('src', '')
        else:
            video = soup.find('video')
            media_url = video.get('src', '') if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except Exception as e:
            print(f"Error getting color: {e}")
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'Batik Ula post'

    # Gabungkan semua comments menjadi satu string
    all_comments = ' | '.join(comments_data) if comments_data else ''

    data.append((
        brand, link, caption, likes, comments_count, all_comments, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Comments: {comments_count} | Likes: {likes}")
    print(f"    📝 Comments preview: {all_comments[:100]}...")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count', 'all_comments',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_Batikula_baru.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_Batikula_baru.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun: Clothing (Brand)
# ✅ Total post ditemukan: 30
# [1] ✅ https://www.instagram.com/batikula/reel/DLd7vk7zNfU/ | reel | Comments: 46 | Likes: 479
#     📝 Comments preview: batikula | Original audio | 😍😍 | Kelass🔥 | LD 110 ada kak | Sebentar lagi akan ada di lemari bajuku ...
# [2] ✅ https://www.instagram.com/batikula/reel/DLbn9Acz2Li/ | reel | Comments: 36 | Likes: 64
#     📝 Comments preview: batikula | LE SSERAFIM•DIFFERENT | Blm punyaa model kyk gini nih😍 | Mauuu | kapan launching kaa? | J...
# [3] ✅ https://www.instagram.com/batikula/reel/DLYpMp0z9eN/ | reel | Comments: 44 | Likes: 137
#     📝 Comments preview: batikula | Original audio | Utami 😍 | Brp kak | Lengannya juga furing dong kak biar ga kusut | Utami...
# [4] ✅ https://www.instagram.com/batikula/p/DLUUkSlzJMd/ | post | Comments: 33 | Likes: 203
#     📝 Comments preview: batikula | Cek harga kak? | June 25 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Lo...
# [5] ✅ https://www.instagram.com/batikula/p/DLRsFj_T5CW/ | post | Comments: 32 | Likes: 51
#     📝 Comments preview: batikula | June 24 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagr...
# [6] ✅ https://www.instagram.com/batikula/reel/DLRWI5kzWWN/ | reel | Comments: 33 | Likes: 95
#     📝 Comments preview: batikula | Original audio | June 24 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Lo...
# [7] ✅ https://www.instagram.com/batikula/p/DLPMgkSTgnt/ | post | Comments: 35 | Likes: 218
#     📝 Comments preview: batikula | Spil hrg | Berapa min? | Kak admin kasih komisi lah buat shopee affiliate🙏🏻😁 | June 23 | ...
# [8] ✅ https://www.instagram.com/batikula/p/DLPMQCwT2fi/ | post | Comments: 33 | Likes: 265
#     📝 Comments preview: batikula | Right🙌 | June 23 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations ...
# [9] ✅ https://www.instagram.com/batikula/reel/DLMPtkmTOzW/ | reel | Comments: 40 | Likes: 60
#     📝 Comments preview: batikula | Original audio | Ada ukuran jumbo ga ka | Cantiq😍 | Bagai mana cara belinya | Mauuuu kak ...
# [10] ✅ https://www.instagram.com/batikula/reel/DLJj7O2TmAG/ | reel | Comments: 39 | Likes: 97
#     📝 Comments preview: batikula | Original audio | 😍😍😍 | Offline storenya ada g kak? | Yg ini gk ada lagi kah😍 | Ini bagian...
# [11] ✅ https://www.instagram.com/batikula/reel/DLEU0RNzG0V/ | reel | Comments: 34 | Likes: 55
#     📝 Comments preview: batikula | Original audio | Seragaman | June 19 | Meta | About | Blog | Jobs | Help | API | Privacy ...
# [12] ✅ https://www.instagram.com/batikula/reel/DK_xOepTNEL/ | reel | Comments: 41 | Likes: 75
#     📝 Comments preview: batikula | Original audio | Astagaaa, apalagi ini milaaa 😍 | 7 🤭 | Udah 9 kak 😍 | Sudah punya 10 😭😂 ...
# [13] ✅ https://www.instagram.com/batikula/p/DK--SAzz2L8/ | post | Comments: 34 | Likes: 65
#     📝 Comments preview: batikula | Sang model pakai size apa min....?? ❤️mauuuu | cara pesannya gimana ya kak? | June 17 | M...
# [14] ✅ https://www.instagram.com/batikula/p/DK8vunNT688/ | post | Comments: 33 | Likes: 93
#     📝 Comments preview: batikula | ❤️yang mau titipp silahkan dr Bogor😍 | June 16 | Meta | About | Blog | Jobs | Help | API ...
# [15] ✅ https://www.instagram.com/batikula/reel/DK5tqrQTHpm/ | reel | Comments: 40 | Likes: 2
#     📝 Comments preview: batikula | Original audio | 😍😍😍😍 | 😍😍😍 | Model pakai size apa kak | Yg ini ada tunik nya ga ya😍 | LD...
# [16] ✅ https://www.instagram.com/batikula/reel/DK3S5VXT4qK/ | reel | Comments: 37 | Likes: 123
#     📝 Comments preview: batikula | Chic•Le Freak (Edit) | MasyaAllah... Cakep milaa... Sabar ya mila gajian sebentar lagi......
# [17] ✅ https://www.instagram.com/batikula/reel/DKzBwJSTbzi/ | reel | Comments: 34 | Likes: 50
#     📝 Comments preview: batikula | Original audio | Kapan restock min? | June 12 | Meta | About | Blog | Jobs | Help | API |...
# [18] ✅ https://www.instagram.com/batikula/p/DKv3y7KTN3b/ | post | Comments: 32 | Likes: 48
#     📝 Comments preview: batikula | June 11 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagr...
# [19] ✅ https://www.instagram.com/batikula/reel/DKtmV3PzLkr/ | reel | Comments: 33 | Likes: 68
#     📝 Comments preview: batikula | Sabrina Carpenter•Manchild | June 10 | Meta | About | Blog | Jobs | Help | API | Privacy ...
# [20] ✅ https://www.instagram.com/batikula/p/DKtGvZCTbdQ/ | post | Comments: 33 | Likes: 144
#     📝 Comments preview: batikula | Aku mau ukuran XL ga kebagian 😢 | June 10 | Meta | About | Blog | Jobs | Help | API | Pri...
# [21] ✅ https://www.instagram.com/batikula/p/DKrlR3hzzvV/ | post | Comments: 41 | Likes: 1,046
#     📝 Comments preview: batikula | Bagus banget | kapan restock di shopee kak | Lucu | Cek harga kak 😊 | Berapa kak??? | Bis...
# [22] ✅ https://www.instagram.com/batikula/reel/DKn3bkFzNOX/ | reel | Comments: 47 | Likes: 2
#     📝 Comments preview: batikula | Ella Fitzgerald•Ooo Baby Baby | Yakksss naksirr bgt inii..panjang soalnyaa | Aku banget s...
# [23] ✅ https://www.instagram.com/batikula/reel/DKlVGV4zCwa/ | reel | Comments: 39 | Likes: 80
#     📝 Comments preview: batikula | Original audio | 😍😍 | Ka ini masih ada ka | Kapan ready di shopee kak? | Cek harga kak | ...
# [24] ✅ https://www.instagram.com/batikula/reel/DKhEQrpz1Yt/ | reel | Comments: 35 | Likes: 43
#     📝 Comments preview: batikula | MALIQ & D'Essentials•Kumpul Bocah (Original Soundtrack From “JUMBO") | Kapan readyny | Di...
# [25] ✅ https://www.instagram.com/batikula/p/DKf98V6zkz4/ | post | Comments: 33 | Likes: 112
#     📝 Comments preview: batikula | ini brp kakk | June 5 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locat...
# [26] ✅ https://www.instagram.com/batikula/reel/DKbzwypB4vE/ | reel | Comments: 33 | Likes: 58
#     📝 Comments preview: batikula | Original audio | June 3 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Loc...
# [27] ✅ https://www.instagram.com/batikula/p/DKa3oazh9t8/ | post | Comments: 37 | Likes: 645
#     📝 Comments preview: batikula | Kak, ini harganya berapa | Kak ini warna abu-abu yaa? | Panjang baju brp cm ka? | Ka masi...
# [28] ✅ https://www.instagram.com/batikula/p/DKYogqGzBPz/ | post | Comments: 39 | Likes: 385
#     📝 Comments preview: batikula | Harga brp kk | stay tune di hari rabu😍😍 | Cek harga kaka | So stunning 👍🏻👌 | admin wa aja...
# [29] ✅ https://www.instagram.com/batikula/reel/DKVwVUUTv-V/ | reel | Comments: 33 | Likes: 50
#     📝 Comments preview: batikula | no na•falling in love | June 1 | Meta | About | Blog | Jobs | Help | API | Privacy | Term...
# [30] ✅ https://www.instagram.com/batikula/reel/DKTTIXBzrMC/ | reel | Comments: 39 | Likes: 263
#     📝 Comments preview: batikula | Original audio | Cantiikk❤️ | Spill tanggal launching nya min cepetan 😍 | Lucu bgt bisa b...
#
# ✅ Selesai! Data disimpan ke 'konten_ig_Batikula_baru.xlsx'
