# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'batikmahkotacom'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Ganti class sesuai hasil inspect element di browser
    kategori_akun = profile_soup.find('div', {'class': '_aa_c'}).text.strip()
except:
    kategori_akun = ''
print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 50
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya"
    while True:
        try:
            load_more = driver.find_element(
                By.XPATH,
                "//button[.//svg[@aria-label='Muat komentar lainnya'] or .//svg[@aria-label='Load more comments']]"
            )
            load_more.click()
            time.sleep(2)
        except NoSuchElementException:
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        caption = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade').text
    except:
        caption = ''

    try:
        likes_div = soup.find('a', class_='x1i10hfl xjbqb8w ...')  # Ganti class sesuai hasil inspect
        likes = likes_div.text if likes_div else ''
    except:
        likes = ''

    try:
        comments_divs = soup.find_all('div', class_='x9f619 xjbqb8w x78zum5 x15mokao x1ga7v0g x16uus16 xbiv7yw x1yztbdb x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1')  # Ganti class sesuai hasil inspect
        comments_count = len(comments_divs)
    except:
        comments_count = 0

    try:
        media = soup.find('img')
        if media:
            media_url = media['src']
        else:
            video = soup.find('video')
            media_url = video['src'] if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except:
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'Batik Mahkota post'

    data.append((
        brand, link, caption, likes, comments_count, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Dominant: {dominant_color} | Name: {color_name}")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_BaktikMahkota.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_BatikMahkota.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun:
# ✅ Total post ditemukan: 42
# [1] ✅ https://www.instagram.com/batikmahkotacom/p/C89lXiYPTsw/ | post | Dominant: (223, 221, 210) | Name: unknown
# [2] ✅ https://www.instagram.com/batikmahkotacom/p/C89lQ_LPQdt/ | post | Dominant: (192, 181, 171) | Name: unknown
# [3] ✅ https://www.instagram.com/batikmahkotacom/p/C89CgJtvGSl/ | post | Dominant: (62, 48, 55) | Name: unknown
# [4] ✅ https://www.instagram.com/batikmahkotacom/p/C89APfxPYs6/ | post | Dominant: (149, 130, 107) | Name: unknown
# [5] ✅ https://www.instagram.com/batikmahkotacom/p/C88_-LCv8w7/ | post | Dominant: (238, 224, 214) | Name: unknown
# [6] ✅ https://www.instagram.com/batikmahkotacom/p/C86KmN7Peud/ | post | Dominant: (219, 215, 205) | Name: unknown
# [7] ✅ https://www.instagram.com/batikmahkotacom/p/C84eG3kPtdU/ | post | Dominant: (210, 182, 147) | Name: unknown
# [8] ✅ https://www.instagram.com/batikmahkotacom/p/C8zS_L4vcge/ | post | Dominant: (218, 205, 184) | Name: unknown
# [9] ✅ https://www.instagram.com/batikmahkotacom/p/C8wqVPsPOMc/ | post | Dominant: (228, 225, 218) | Name: unknown
# [10] ✅ https://www.instagram.com/batikmahkotacom/p/C8wqNTUPO4w/ | post | Dominant: (76, 52, 40) | Name: unknown
# [11] ✅ https://www.instagram.com/batikmahkotacom/p/C8wpyIAv9nd/ | post | Dominant: (201, 197, 186) | Name: unknown
# [12] ✅ https://www.instagram.com/batikmahkotacom/p/C8wptpVvJrR/ | post | Dominant: (218, 207, 188) | Name: unknown
# [13] ✅ https://www.instagram.com/batikmahkotacom/p/C8wC_jqPHdy/ | post | Dominant: (200, 196, 189) | Name: unknown
# [14] ✅ https://www.instagram.com/batikmahkotacom/p/C8wCyx1vSOD/ | post | Dominant: (223, 217, 207) | Name: unknown
# [15] ✅ https://www.instagram.com/batikmahkotacom/p/C8uApCVvRD9/ | post | Dominant: (217, 208, 200) | Name: unknown
# [16] ✅ https://www.instagram.com/batikmahkotacom/p/C8uAhDNPf9Z/ | post | Dominant: (217, 214, 213) | Name: unknown
# [17] ✅ https://www.instagram.com/batikmahkotacom/p/C8o3q2XvhdC/ | post | Dominant: (173, 105, 76) | Name: unknown
# [18] ✅ https://www.instagram.com/batikmahkotacom/p/C8o3jSTPJg9/ | post | Dominant: (238, 220, 206) | Name: unknown
# [19] ✅ https://www.instagram.com/batikmahkotacom/p/C8o3UtpPtWT/ | post | Dominant: (80, 60, 45) | Name: unknown
# [20] ✅ https://www.instagram.com/batikmahkotacom/p/C8nmOnSPOoZ/ | post | Dominant: (204, 197, 191) | Name: unknown
# [21] ✅ https://www.instagram.com/batikmahkotacom/p/C8nmHIkPRup/ | post | Dominant: (219, 215, 209) | Name: unknown
# [22] ✅ https://www.instagram.com/batikmahkotacom/p/C8j1ZHEvhN0/ | post | Dominant: (218, 215, 210) | Name: unknown
# [23] ✅ https://www.instagram.com/batikmahkotacom/p/C8cOomxvhvb/ | post | Dominant: (219, 216, 199) | Name: unknown
# [24] ✅ https://www.instagram.com/batikmahkotacom/p/C8cOU8NP6uf/ | post | Dominant: (43, 36, 37) | Name: unknown
# [25] ✅ https://www.instagram.com/batikmahkotacom/p/C8cOIEavhvZ/ | post | Dominant: (200, 189, 191) | Name: unknown
# [26] ✅ https://www.instagram.com/batikmahkotacom/p/C8cN5VQvV0w/ | post | Dominant: (219, 219, 214) | Name: unknown
# [27] ✅ https://www.instagram.com/batikmahkotacom/p/C8bLzRLvGqG/ | post | Dominant: (213, 210, 194) | Name: unknown
# [28] ✅ https://www.instagram.com/batikmahkotacom/p/C8bLdxMv2zC/ | post | Dominant: (191, 180, 167) | Name: unknown
# [29] ✅ https://www.instagram.com/batikmahkotacom/p/C8bLU-evLqF/ | post | Dominant: (195, 186, 176) | Name: unknown
# [30] ✅ https://www.instagram.com/batikmahkotacom/p/C8bLN-Wv_Ba/ | post | Dominant: (168, 165, 161) | Name: unknown
# [31] ✅ https://www.instagram.com/batikmahkotacom/p/C8atEhJPU3v/ | post | Dominant: (216, 214, 209) | Name: unknown
# [32] ✅ https://www.instagram.com/batikmahkotacom/p/C8Ymm_evdZT/ | post | Dominant: (214, 214, 203) | Name: unknown
# [33] ✅ https://www.instagram.com/batikmahkotacom/p/C8YmZW9Ph6e/ | post | Dominant: (214, 203, 193) | Name: unknown
# [34] ✅ https://www.instagram.com/batikmahkotacom/p/C8YlsW6vV_K/ | post | Dominant: (205, 194, 186) | Name: unknown
# [35] ✅ https://www.instagram.com/batikmahkotacom/p/C8TC587v606/ | post | Dominant: (227, 226, 220) | Name: unknown
# [36] ✅ https://www.instagram.com/batikmahkotacom/p/C8PRqIjPEa3/ | post | Dominant: (216, 210, 190) | Name: unknown
# [37] ✅ https://www.instagram.com/batikmahkotacom/p/C8PQqVlPnI7/ | post | Dominant: (214, 213, 208) | Name: unknown
# [38] ✅ https://www.instagram.com/batikmahkotacom/p/C8MgqU0PSzT/ | post | Dominant: (215, 206, 192) | Name: unknown
# [39] ✅ https://www.instagram.com/batikmahkotacom/p/C8JRzCuvEQW/ | post | Dominant: (223, 217, 202) | Name: unknown
# [40] ✅ https://www.instagram.com/batikmahkotacom/p/C8JRecLPdFW/ | post | Dominant: (66, 63, 60) | Name: unknown
# [41] ✅ https://www.instagram.com/batikmahkotacom/p/C8I62nvPKPe/ | post | Dominant: (234, 220, 215) | Name: unknown
# [42] ✅ https://www.instagram.com/batikmahkotacom/p/C8I6l4mvs02/ | post | Dominant: (232, 220, 217) | Name: unknown
#
# ✅ Selesai! Data disimpan ke 'konten_ig_BatikMahkota.xlsx'
