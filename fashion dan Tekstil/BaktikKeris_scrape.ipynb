# %%
import time
import requests
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
from colorthief import ColorThief
import webcolors
import re

# === Fungsi helper: RGB ke nama warna ===
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(rgb_color):
    try:
        return closest_color(rgb_color)
    except Exception:
        return 'unknown'

# === Fungsi untuk mengambil comments ===
def get_comments_data(driver, soup):
    comments_data = []
    comments_count = 0
    
    # Metode 1: Cari berdasarkan struktur HTML yang lebih stabil
    try:
        # Cari semua span yang berisi teks comment
        comment_spans = soup.find_all('span', dir='auto')
        
        for span in comment_spans:
            # Skip jika span berisi username atau caption
            parent = span.parent
            if parent and parent.name == 'h1':  # Skip caption
                continue
                
            text = span.get_text(strip=True)
            if text and len(text) > 1:  # Filter teks yang valid
                # Cek apakah ini bukan username (biasanya ada @ atau link)
                if not text.startswith('@') and 'href' not in str(span):
                    comments_data.append(text)
                    comments_count += 1
    except Exception as e:
        print(f"Error metode 1: {e}")
    
    # Metode 2: Cari dengan XPath yang lebih fleksibel
    try:
        comment_elements = driver.find_elements(By.XPATH, "//div[@role='button']//span[contains(@dir, 'auto')]")
        
        for element in comment_elements:
            text = element.text.strip()
            if text and len(text) > 1 and text not in comments_data:
                # Filter yang bukan username atau action
                if not any(keyword in text.lower() for keyword in ['like', 'reply', 'follow', 'view']):
                    comments_data.append(text)
                    comments_count += 1
    except Exception as e:
        print(f"Error metode 2: {e}")
    
    # Metode 3: Cari berdasarkan aria-label
    try:
        comment_sections = soup.find_all('div', {'aria-label': re.compile(r'comment', re.I)})
        for section in comment_sections:
            spans = section.find_all('span')
            for span in spans:
                text = span.get_text(strip=True)
                if text and len(text) > 1 and text not in comments_data:
                    comments_data.append(text)
                    comments_count += 1
    except Exception as e:
        print(f"Error metode 3: {e}")
    
    # Metode 4: Cari dengan pattern yang lebih umum
    try:
        # Cari elemen yang kemungkinan berisi comment
        potential_comments = soup.find_all('span', string=re.compile(r'.{2,}'))
        
        for span in potential_comments:
            text = span.get_text(strip=True)
            parent_class = span.parent.get('class', []) if span.parent else []
            
            # Filter berdasarkan konteks
            if (text and len(text) > 1 and 
                text not in comments_data and
                not text.startswith('@') and
                not any(keyword in text.lower() for keyword in ['like', 'reply', 'follow', 'view', 'ago', 'hour', 'day', 'week'])):
                comments_data.append(text)
                comments_count += 1
    except Exception as e:
        print(f"Error metode 4: {e}")
    
    return comments_data, comments_count

# === Fungsi untuk mengambil likes dengan lebih akurat ===
def get_likes_count(soup):
    try:
        # Metode 1: Cari berdasarkan pattern "X likes"
        likes_pattern = soup.find('a', string=re.compile(r'\d+.*like', re.I))
        if likes_pattern:
            likes_text = likes_pattern.get_text()
            numbers = re.findall(r'[\d,]+', likes_text)
            return numbers[0] if numbers else ''
        
        # Metode 2: Cari berdasarkan struktur button
        likes_button = soup.find('button', {'aria-label': re.compile(r'like', re.I)})
        if likes_button:
            likes_text = likes_button.get_text()
            numbers = re.findall(r'[\d,]+', likes_text)
            return numbers[0] if numbers else ''
        
        # Metode 3: Cari span yang berisi angka + "likes"
        all_spans = soup.find_all('span')
        for span in all_spans:
            text = span.get_text().lower()
            if 'like' in text and any(char.isdigit() for char in text):
                numbers = re.findall(r'[\d,]+', text)
                return numbers[0] if numbers else ''
                
    except Exception as e:
        print(f"Error getting likes: {e}")
    
    return ''

# === Setup Chrome ===
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# === Login manual ===
driver.get('https://www.instagram.com/')
print("🔑 Silakan login manual dulu...")
time.sleep(40)

# === Profil target ===
username_target = 'batikkerisonline'
profile_url = f'https://www.instagram.com/{username_target}/'
driver.get(profile_url)
time.sleep(5)

# === Ambil kategori akun dari profil ===
profile_soup = BeautifulSoup(driver.page_source, 'html.parser')
try:
    # Cari dengan berbagai metode
    kategori_akun = ''
    
    # Metode 1: Cari berdasarkan struktur profile
    category_divs = profile_soup.find_all('div', string=re.compile(r'Business|Shopping|Brand|Store', re.I))
    if category_divs:
        kategori_akun = category_divs[0].get_text().strip()
    
    # Metode 2: Backup jika tidak ketemu
    if not kategori_akun:
        bio_sections = profile_soup.find_all('div', {'class': re.compile(r'_aa_c')})
        for section in bio_sections:
            text = section.get_text().strip()
            if text and len(text) < 100:  # Kategori biasanya pendek
                kategori_akun = text
                break
                
except Exception as e:
    kategori_akun = ''
    print(f"Error getting category: {e}")

print(f"✅ Kategori akun: {kategori_akun}")

# === Scroll agar semua post muncul ===
scroll_times = 50
for _ in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

# === Ambil semua link post & reels ===
post_links = []
posts = driver.find_elements(By.XPATH, '//a[contains(@href, "/p/") or contains(@href, "/reel/")]')
for post in posts:
    href = post.get_attribute('href')
    if href not in post_links:
        post_links.append(href)

print(f"✅ Total post ditemukan: {len(post_links)}")

# Batasi (misal ambil 100 post)
post_links = post_links[:100]

# === DATA OUTPUT ===
data = []

# === Loop setiap post ===
for idx, link in enumerate(post_links):
    driver.get(link)
    time.sleep(5)

    # Tentukan jenis konten
    if '/reel/' in link:
        media_type = 'reel'
    elif '/p/' in link:
        media_type = 'post'
    else:
        media_type = ''

    # Klik "Muat komentar lainnya" dengan lebih banyak variasi
    load_more_attempts = 0
    max_load_attempts = 10
    
    while load_more_attempts < max_load_attempts:
        try:
            # Coba berbagai selector untuk tombol load more
            load_more_selectors = [
                "//button[.//svg[@aria-label='Muat komentar lainnya']]",
                "//button[.//svg[@aria-label='Load more comments']]",
                "//button[contains(text(), 'View more comments')]",
                "//button[contains(text(), 'Lihat komentar lainnya')]",
                "//span[contains(text(), 'View more comments')]",
                "//span[contains(text(), 'Lihat komentar lainnya')]"
            ]
            
            load_more_found = False
            for selector in load_more_selectors:
                try:
                    load_more = driver.find_element(By.XPATH, selector)
                    load_more.click()
                    load_more_found = True
                    time.sleep(2)
                    break
                except NoSuchElementException:
                    continue
            
            if not load_more_found:
                break
                
            load_more_attempts += 1
            
        except Exception as e:
            print(f"Error loading more comments: {e}")
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Ambil data
    brand = username_target

    try:
        # Cari caption dengan berbagai metode
        caption = ''
        
        # Metode 1: Cari h1 dengan class spesifik
        caption_h1 = soup.find('h1', class_='_ap3a _aaco _aacu _aacx _aad7 _aade')
        if caption_h1:
            caption = caption_h1.get_text().strip()
        
        # Metode 2: Cari berdasarkan struktur yang lebih umum
        if not caption:
            meta_desc = soup.find('meta', {'name': 'description'})
            if meta_desc:
                caption = meta_desc.get('content', '')
        
        # Metode 3: Cari span dengan teks panjang di area post
        if not caption:
            spans = soup.find_all('span', dir='auto')
            for span in spans:
                text = span.get_text().strip()
                if len(text) > 20:  # Caption biasanya lebih panjang
                    caption = text
                    break
                    
    except Exception as e:
        caption = ''
        print(f"Error getting caption: {e}")

    # Ambil likes dengan fungsi yang diperbaiki
    likes = get_likes_count(soup)

    # Ambil comments dengan fungsi yang diperbaiki
    comments_data, comments_count = get_comments_data(driver, soup)

    try:
        media = soup.find('img')
        if media:
            media_url = media.get('src', '')
        else:
            video = soup.find('video')
            media_url = video.get('src', '') if video else ''
    except:
        media_url = ''

    # Ambil dominant color
    dominant_color = ''
    color_name = ''
    if media_url and media_type == 'post':
        try:
            response = requests.get(media_url)
            img = BytesIO(response.content)
            ct = ColorThief(img)
            dominant_color = ct.get_color(quality=1)
            color_name = get_color_name(dominant_color)
        except Exception as e:
            print(f"Error getting color: {e}")
            dominant_color = ''
            color_name = ''

    try:
        upload_time = soup.find('time')['datetime']
    except:
        upload_time = ''

    content_category = 'Batik Keris post'

    # Gabungkan semua comments menjadi satu string
    all_comments = ' | '.join(comments_data) if comments_data else ''

    data.append((
        brand, link, caption, likes, comments_count, all_comments, media_url, media_type,
        str(dominant_color), color_name, content_category, upload_time, kategori_akun
    ))

    print(f"[{idx+1}] ✅ {link} | {media_type} | Comments: {comments_count} | Likes: {likes}")
    print(f"    📝 Comments preview: {all_comments[:100]}...")
    time.sleep(2)

# === Save ke Excel ===
df = pd.DataFrame(data, columns=[
    'brand', 'url_post', 'caption', 'likes', 'comments_count', 'all_comments',
    'media_url', 'media_type', 'dominant_color', 'color_name',
    'content_category', 'upload_time', 'profile_category'
])

df.to_excel('konten_ig_BatikKeris.xlsx', index=False)
print("\n✅ Selesai! Data disimpan ke 'konten_ig_BatikKeris.xlsx'")

driver.quit()
# Out:
# 🔑 Silakan login manual dulu...
# ✅ Kategori akun: Clothing (Brand)
# ✅ Total post ditemukan: 42
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/431498969_419094697244214_2629537804814727252_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=106&_nc_oc=Q6cZ2QEpidgkoRBz8gZP6kZz7qQizOuYVI5ssS4bhdv3Hf3wOOSdza3GZJjRTAPeIUfkrxo&_nc_ohc=1iIB6nO8vvQQ7kNvwF2MGy2&_nc_gid=2aDCwo6LDD2LmAHP1jA2yQ&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxNjAxNDQyNzg5NTYzMDQ1NA%3D%3D.3-ccb7-5&oh=00_AfQPTXWizvTmRGzwZC_kip_E9a0yNjX5g5-xYUMm3NqW3g&oe=687E2239&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221C996A3F0>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [1] ✅ https://www.instagram.com/batikkerisonline/p/C4E2Y8ZSKdn/ | post | Comments: 36 | Likes: 34
#     📝 Comments preview: March 4, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [2] ✅ https://www.instagram.com/batikkerisonline/p/C4E2TuByYAz/ | post | Comments: 35 | Likes: 31
#     📝 Comments preview: March 4, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [3] ✅ https://www.instagram.com/batikkerisonline/p/C4ABFf_SuVs/ | post | Comments: 35 | Likes: 30
#     📝 Comments preview: March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [4] ✅ https://www.instagram.com/batikkerisonline/p/C4AA9G5SmBg/ | post | Comments: 35 | Likes: 18
#     📝 Comments preview: March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [5] ✅ https://www.instagram.com/batikkerisonline/p/C4AAoYOSc5z/ | post | Comments: 35 | Likes: 43
#     📝 Comments preview: March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [6] ✅ https://www.instagram.com/batikkerisonline/p/C4AAb-MSgwx/ | post | Comments: 37 | Likes: 40
#     📝 Comments preview: doble XL size berapa pas nya min? | March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privac...
# [7] ✅ https://www.instagram.com/batikkerisonline/p/C3_i9NBy9WU/ | post | Comments: 35 | Likes: 25
#     📝 Comments preview: March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [8] ✅ https://www.instagram.com/batikkerisonline/p/C3_i1n2yyi7/ | post | Comments: 35 | Likes: 31
#     📝 Comments preview: March 2, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/430361434_718661850441550_4144681748362837625_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=110&_nc_oc=Q6cZ2QHNaNCdX-xNMKroPkwxRuXvNLWGbChyR46Be5CIOTuHgMTj8jQIGDSYT6ZFEeAWLCI&_nc_ohc=Obqr-mISlwYQ7kNvwGuylIt&_nc_gid=9qHIKWeBMryPdmKXAkTR6A&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxMzg1OTY3MTg0NDcwMDMwNw%3D%3D.3-ccb7-5&oh=00_AfREJWOmJDXdtngIQi2Mqr4EbPa7r9keJG92nOJDKRI8lw&oe=687E4755&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221C9A2C650>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [9] ✅ https://www.instagram.com/batikkerisonline/p/C39MdFqyIdL/ | post | Comments: 35 | Likes: 42
#     📝 Comments preview: March 1, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagram Li...
# [10] ✅ https://www.instagram.com/batikkerisonline/p/C39MX6zyojU/ | post | Comments: 37 | Likes: 51
#     📝 Comments preview: Apakah model ini masih ada? | March 1, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Te...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/430789809_969436841191414_4117787134040755547_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=110&_nc_oc=Q6cZ2QHKft1MpdlpTF9Wulx5gdST3rNoIzJFjaLFSYz2Ib5xiEWdNTkFlzh0BjAkMixwyz0&_nc_ohc=__oV-YqOtcQQ7kNvwFv1pz6&_nc_gid=OQrDvnTchOuVlh443q8JNw&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxMzA5MTc1NTcyNTQ3OTkwNg%3D%3D.3-ccb7-5&oh=00_AfTbkFXvVVkerrRUS6vHwDdo8Q539vdJrYslJBgtzYWoGg&oe=687E4AD8&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221C98EB5C0>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [11] ✅ https://www.instagram.com/batikkerisonline/p/C36d2cDy_im/ | post | Comments: 38 | Likes: 31
#     📝 Comments preview: Yg ini ready dmna yah min? | February 29, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy |...
# [12] ✅ https://www.instagram.com/batikkerisonline/p/C36dx8NSeF-/ | post | Comments: 37 | Likes: 28
#     📝 Comments preview: Ready kah Ka? | February 29, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Loca...
# [13] ✅ https://www.instagram.com/batikkerisonline/p/C34XtLGy47j/ | post | Comments: 35 | Likes: 39
#     📝 Comments preview: February 28, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [14] ✅ https://www.instagram.com/batikkerisonline/p/C34Xn1LyNN-/ | post | Comments: 35 | Likes: 32
#     📝 Comments preview: February 28, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [15] ✅ https://www.instagram.com/batikkerisonline/p/C31pSrbyMrf/ | post | Comments: 35 | Likes: 44
#     📝 Comments preview: February 27, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/430118752_3707304162923686_5553065140845706681_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=110&_nc_oc=Q6cZ2QEdKaoe1SEgODbZKAZSaOSdf47v1ORVtJUKIfSaiMvroUesK9hBACrRLKuZmLkiF1g&_nc_ohc=Poq5dUjJyWIQ7kNvwECpfSL&_nc_gid=TD1QMrBHJG0GBLko9oWg6w&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxMTczNDE1NDg0ODY0Mjc2OA%3D%3D.3-ccb7-5&oh=00_AfQiuKvpf-RKDC3QApj5SyDLF-aX2k5BQQSHl_ouwUFsdw&oe=687E3B55&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221CACE2E40>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [16] ✅ https://www.instagram.com/batikkerisonline/p/C31pKw1SX76/ | post | Comments: 35 | Likes: 31
#     📝 Comments preview: February 27, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/429757384_1319742862024514_7017022243112722006_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=102&_nc_oc=Q6cZ2QF1HoUgfNFN1BQYsHBvMctkRfX_gLAOhjOKO0az_RwDvCr3N2ZdpcpVg7_4nAEf5qM&_nc_ohc=3UJmpS75hb8Q7kNvwGDwYoE&_nc_gid=Eg7Wg95srlrtW0TYbbX4FQ&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxMDk5MTQzNTE3MjEyNDUxMw%3D%3D.3-ccb7-5&oh=00_AfTpFsHmgmd2CsfcWRQvwTVKraL50-Qbzl6Bm5G3XFVn2A&oe=687E1881&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221C9E3C440>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [17] ✅ https://www.instagram.com/batikkerisonline/p/C3zASwbSgkA/ | post | Comments: 37 | Likes: 18
#     📝 Comments preview: Yg ini ada couple annya gak miin? | February 26, 2024 | Meta | About | Blog | Jobs | Help | API | Pr...
# [18] ✅ https://www.instagram.com/batikkerisonline/p/C3y_6KEyYu-/ | post | Comments: 35 | Likes: 36
#     📝 Comments preview: February 26, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/429495743_725303249754986_6073502573003186224_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=102&_nc_oc=Q6cZ2QH42t0oqVXCJ_ZpyoNJ6q5Lkrabnf27aMBRM0ySbDL4EmBHhzS8dnUVCzV5YUQDEKA&_nc_ohc=RPV_N42_6IMQ7kNvwG9_LN3&_nc_gid=cC7_zKWQ4yiBFpAHMlrooA&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMxMDI1OTM4NjQ5MjQwOTg0Mw%3D%3D.3-ccb7-5&oh=00_AfTHJXztx_Hgt6K_FkrCSqwu6ZUOfh_fQORypr7iAeSaNw&oe=687E4019&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221CAAC8D10>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [19] ✅ https://www.instagram.com/batikkerisonline/p/C3wZ2DZyoun/ | post | Comments: 35 | Likes: 39
#     📝 Comments preview: February 25, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [20] ✅ https://www.instagram.com/batikkerisonline/p/C3trMV7yWcS/ | post | Comments: 35 | Likes: 19
#     📝 Comments preview: February 24, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [21] ✅ https://www.instagram.com/batikkerisonline/p/C3trI2kSc7-/ | post | Comments: 35 | Likes: 33
#     📝 Comments preview: February 24, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [22] ✅ https://www.instagram.com/batikkerisonline/p/C3romtCy0_K/ | post | Comments: 35 | Likes: 31
#     📝 Comments preview: February 23, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [23] ✅ https://www.instagram.com/batikkerisonline/p/C3roZCNSoh0/ | post | Comments: 35 | Likes: 18
#     📝 Comments preview: February 23, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [24] ✅ https://www.instagram.com/batikkerisonline/p/C3pKH9pywXK/ | post | Comments: 35 | Likes: 18
#     📝 Comments preview: February 22, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [25] ✅ https://www.instagram.com/batikkerisonline/p/C3pKDRUS2NW/ | post | Comments: 35 | Likes: 21
#     📝 Comments preview: February 22, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [26] ✅ https://www.instagram.com/batikkerisonline/p/C3ouC_HyX5z/ | post | Comments: 35 | Likes: 22
#     📝 Comments preview: February 22, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [27] ✅ https://www.instagram.com/batikkerisonline/p/C3mLZSgyORK/ | post | Comments: 35 | Likes: 35
#     📝 Comments preview: February 21, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/428969673_2021281304914274_3008551706318441848_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=102&_nc_oc=Q6cZ2QEIjIRqUEX_yZY8D_UH2EH4Eezg-o1BaeQLF9EcKtiq6Q9GYSz5r9Q9T1QBeGrqqe4&_nc_ohc=YdCZFqcYc9cQ7kNvwFdkc7i&_nc_gid=F5BUXkmdJ7t4I-urxuStog&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMwNzM4MDc2MTM5Mjk2ODg5Mw%3D%3D.3-ccb7-5&oh=00_AfRI3lKXvtN0XBO_LgEaCOf5mWejJjpxv4wuNl-QOgCCqg&oe=687E3630&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221CBB83CB0>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [28] ✅ https://www.instagram.com/batikkerisonline/p/C3mLUjeyPEy/ | post | Comments: 35 | Likes: 20
#     📝 Comments preview: February 21, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [29] ✅ https://www.instagram.com/batikkerisonline/p/C3mLPuZSbOl/ | post | Comments: 35 | Likes: 13
#     📝 Comments preview: February 21, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [30] ✅ https://www.instagram.com/batikkerisonline/p/C3j69D3SweB/ | post | Comments: 35 | Likes: 32
#     📝 Comments preview: February 20, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [31] ✅ https://www.instagram.com/batikkerisonline/p/C3j64sWSbUf/ | post | Comments: 37 | Likes: 27
#     📝 Comments preview: Apakah ini batik tulis? | February 20, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Te...
# [32] ✅ https://www.instagram.com/batikkerisonline/p/C3jbXFTyF3D/ | post | Comments: 35 | Likes: 20
#     📝 Comments preview: February 20, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [33] ✅ https://www.instagram.com/batikkerisonline/p/C3jbSUmS2RA/ | post | Comments: 35 | Likes: 21
#     📝 Comments preview: February 20, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [34] ✅ https://www.instagram.com/batikkerisonline/p/C3hC-xRSGHj/ | post | Comments: 35 | Likes: 29
#     📝 Comments preview: February 19, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [35] ✅ https://www.instagram.com/batikkerisonline/p/C3hC6HiS5fO/ | post | Comments: 35 | Likes: 28
#     📝 Comments preview: February 19, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [36] ✅ https://www.instagram.com/batikkerisonline/p/C3evO8SSQH3/ | post | Comments: 37 | Likes: 36
#     📝 Comments preview: Sukses selalu ya kak, semoga bisa kami bantu kirim sampai ke luar negeri ya | February 18, 2024 | Me...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/428873344_1107383307263555_4821128786050552186_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=111&_nc_oc=Q6cZ2QFNt5HXiTIpJ2l353NPn0BV_aokC5JaQFQQnBnuiWrYGOEDL4TepsjMOPQX0NQzKdA&_nc_ohc=Cg5iY8IjkZcQ7kNvwFEpgAX&_nc_gid=LdCRCQOGTwMpn5b6JjmvOg&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMwNTI4NjUyNDQ0MjcyMjc5Mw%3D%3D.3-ccb7-5&oh=00_AfQO9HnUqDH_iq23NfIrt9TiPytCNph8vq32guOtDrYZnw&oe=687E1825&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221C9BBD2E0>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [37] ✅ https://www.instagram.com/batikkerisonline/p/C3evJXiSzPv/ | post | Comments: 35 | Likes: 17
#     📝 Comments preview: February 18, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [38] ✅ https://www.instagram.com/batikkerisonline/p/C3brEY3SuKf/ | post | Comments: 35 | Likes: 32
#     📝 Comments preview: February 17, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [39] ✅ https://www.instagram.com/batikkerisonline/p/C3brA-8yBuV/ | post | Comments: 35 | Likes: 19
#     📝 Comments preview: February 17, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# [40] ✅ https://www.instagram.com/batikkerisonline/p/C3ZN472ykDk/ | post | Comments: 37 | Likes: 31
#     📝 Comments preview: ini ready-kah? | February 16, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Loc...
# [41] ✅ https://www.instagram.com/batikkerisonline/p/C3ZNpmVydaK/ | post | Comments: 35 | Likes: 25
#     📝 Comments preview: February 16, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
# Error getting color: HTTPSConnectionPool(host='instagram.fsub8-1.fna.fbcdn.net', port=443): Max retries exceeded with url: /v/t51.29350-15/427430725_1474421586822134_6170253041793885712_n.webp?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjEwODB4MTA4MC5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=instagram.fsub8-1.fna.fbcdn.net&_nc_cat=102&_nc_oc=Q6cZ2QFg6KA-cIZPxXLWTeW7uzfTNrbfhqtulJ-ihbZXeFDfMfhmch6VJtl5wGNAaW378-s&_nc_ohc=Y3siDHNPc8wQ7kNvwEMjfS1&_nc_gid=SAVfxdyPvLAzV7_9XAWfpw&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMwMzcyNDM5NDA0NDEwOTYyNg%3D%3D.3-ccb7-5&oh=00_AfR3C46uPOG037mzlUYvNn_loTRKo1tYU2gTFLLfCQDfFg&oe=687E4D99&_nc_sid=fc8dfb (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000221CB6104D0>, 'Connection to instagram.fsub8-1.fna.fbcdn.net timed out. (connect timeout=None)'))
# [42] ✅ https://www.instagram.com/batikkerisonline/p/C3ZL9Z4y3T7/ | post | Comments: 35 | Likes: 46
#     📝 Comments preview: February 16, 2024 | Meta | About | Blog | Jobs | Help | API | Privacy | Terms | Locations | Instagra...
#
# ✅ Selesai! Data disimpan ke 'konten_ig_BatikKeris.xlsx'
